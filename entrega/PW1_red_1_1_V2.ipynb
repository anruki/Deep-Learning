# %%
# %load_ext tensorboard

# %%
# Borra recursivamente las carpetas train, test y logs si existen
#!rm -rf train/
#!rm -rf test/
#!rm -rf logs/

# %%
# from google.colab import files
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from keras.callbacks import TensorBoard
from keras.preprocessing import image
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc
from sklearn.model_selection import StratifiedShuffleSplit
from keras.callbacks import TensorBoard


import numpy as np
import seaborn as sns
import tensorflow as tf
import os
import zipfile
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
# Establecer la semilla global
seed_value = 42
tf.random.set_seed(seed_value)

# %%
local_zip = './ima_train.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('./train')
local_zip = './ima_test.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('./test')
local_zip = './ima_val.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('./validation')
zip_ref.close()

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    './train',
    image_size=(96, 96),
    batch_size=128,
    label_mode='categorical' 
)

val_dataset = image_dataset_from_directory(
    './validation',
    image_size=(96, 96),
    batch_size=128,
    label_mode='categorical'
)

test_dataset = image_dataset_from_directory(
    './test',
    image_size=(96, 96),
    batch_size=128,
    label_mode='categorical',
    shuffle=False  # Para evaluar correctamente
)
# Out:
# Found 1113 files belonging to 7 classes.
# Found 245 files belonging to 7 classes.
# Found 238 files belonging to 7 classes.

# %%
# Creamos una carpeta para guardar los modelos entrenados
save_dir = "saved_models"
os.makedirs(save_dir, exist_ok=True)
histories = []  #guardaremos accuracy, pérdida...
models = []     # guardaremos los modelos ya entrenados
log_dirs=[]     #guardaremos las rutas

# %%
from tensorflow import keras

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',  # Monitoreamos la pérdida en validación
    factor=0.5,          # Reducimos la LR a la mitad cuando no mejora
    patience=3,          # Esperamos 3 épocas antes de reducir
    min_lr=1e-6          # Establecemos un límite mínimo para la LR
)

# %%
#  Entrenamos los 3 modelos
kernel_sizes = [(3,3), (5,5), (3,3)]
pool_sizes = [(3,3), (2,2), (2,2)]
learning_rates = [0.001, 0.0005, 0.01]
dense_configs = [512, 128, 512]
epochs = [20, 15, 25]

input_size = 96
num_colors = 3

models = []
histories = []
log_dirs = []

for i in range(3):
    print(f"\nTraining model {i+1} with LR={learning_rates[i]}, Kernel={kernel_sizes[i]}, Pool={pool_sizes[i]}, Dense={dense_configs[i]}")
    model = keras.Sequential()

    model.add(keras.layers.Conv2D(16, kernel_sizes[i], activation='relu', input_shape=(input_size, input_size, num_colors)))
    model.add(keras.layers.MaxPooling2D(pool_sizes[i]))

    model.add(keras.layers.Conv2D(32, kernel_sizes[i], activation='relu'))
    model.add(keras.layers.MaxPooling2D(pool_sizes[i]))

    model.add(keras.layers.Conv2D(64, kernel_sizes[i], activation='relu'))
    model.add(keras.layers.MaxPooling2D(pool_sizes[i]))

    if i >= 1:
        model.add(keras.layers.Conv2D(128, kernel_sizes[i], activation='relu'))
        model.add(keras.layers.MaxPooling2D(pool_sizes[i]))

    if i == 2:
        model.add(keras.layers.Conv2D(128, kernel_sizes[i], activation='relu'))  # sin pooling final

    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(dense_configs[i], activation='relu'))
    model.add(keras.layers.Dropout(0.4))
    model.add(keras.layers.Dense(7, activation='softmax'))

    optimizer = keras.optimizers.RMSprop(learning_rate=learning_rates[i])
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    log_dir = os.path.join("logs", f"model_{i+1}")
    tensorboard_callback = keras.callbacks.TensorBoard(log_dir=log_dir)

    # Entrenamos el modelo
    history = model.fit(train_dataset, epochs=epochs[i], validation_data=val_dataset, callbacks=[tensorboard_callback, reduce_lr])


    # Guardamos el modelo entrenado
    models.append(model)
    histories.append(history)
    log_dirs.append(log_dir)
# Out:
# Training model 1 with LR=0.001, Kernel=(3, 3), Pool=(3, 3), Dense=512
# Epoch 1/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - accuracy: 0.1714 - loss: 21.4677 - val_accuracy: 0.2571 - val_loss: 1.9162 - learning_rate: 0.0010
# Epoch 2/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.3046 - loss: 1.9906 - val_accuracy: 0.3347 - val_loss: 1.6784 - learning_rate: 0.0010
# Epoch 3/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.3339 - loss: 1.7336 - val_accuracy: 0.3755 - val_loss: 1.5779 - learning_rate: 0.0010
# Epoch 4/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - accuracy: 0.3761 - loss: 1.7364 - val_accuracy: 0.3551 - val_loss: 1.6458 - learning_rate: 0.0010
# Epoch 5/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 0.3899 - loss: 1.5937 - val_accuracy: 0.4041 - val_loss: 1.4930 - learning_rate: 0.0010
# Epoch 6/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 0.3908 - loss: 1.5543 - val_accuracy: 0.3020 - val_loss: 1.6646 - learning_rate: 0.0010
# Epoch 7/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.4185 - loss: 1.5011 - val_accuracy: 0.4327 - val_loss: 1.3843 - learning_rate: 0.0010
# Epoch 8/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - accuracy: 0.4672 - loss: 1.4389 - val_accuracy: 0.4327 - val_loss: 1.4067 - learning_rate: 0.0010
# Epoch 9/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.4860 - loss: 1.3004 - val_accuracy: 0.3796 - val_loss: 1.8524 - learning_rate: 0.0010
# Epoch 10/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.4329 - loss: 1.7341 - val_accuracy: 0.4327 - val_loss: 1.4806 - learning_rate: 0.0010
# Epoch 11/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.5883 - loss: 1.0954 - val_accuracy: 0.5306 - val_loss: 1.2316 - learning_rate: 5.0000e-04
# Epoch 12/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.6709 - loss: 0.8551 - val_accuracy: 0.5755 - val_loss: 1.1043 - learning_rate: 5.0000e-04
# Epoch 13/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.7160 - loss: 0.7705 - val_accuracy: 0.6163 - val_loss: 1.0333 - learning_rate: 5.0000e-04
# Epoch 14/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 0.7058 - loss: 0.7473 - val_accuracy: 0.5918 - val_loss: 1.0893 - learning_rate: 5.0000e-04
# Epoch 15/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 0.7621 - loss: 0.6262 - val_accuracy: 0.6286 - val_loss: 0.9757 - learning_rate: 5.0000e-04
# Epoch 16/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.7714 - loss: 0.6306 - val_accuracy: 0.6776 - val_loss: 0.8602 - learning_rate: 5.0000e-04
# Epoch 17/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.8027 - loss: 0.5698 - val_accuracy: 0.6735 - val_loss: 0.8854 - learning_rate: 5.0000e-04
# Epoch 18/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 0.8734 - loss: 0.4005 - val_accuracy: 0.6816 - val_loss: 0.9294 - learning_rate: 5.0000e-04
# Epoch 19/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.8176 - loss: 0.5031 - val_accuracy: 0.6531 - val_loss: 1.0600 - learning_rate: 5.0000e-04
# Epoch 20/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.8492 - loss: 0.4204 - val_accuracy: 0.7224 - val_loss: 0.8154 - learning_rate: 2.5000e-04
#
# Training model 2 with LR=0.0005, Kernel=(5, 5), Pool=(2, 2), Dense=128
# Epoch 1/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 264ms/step - accuracy: 0.1520 - loss: 32.6829 - val_accuracy: 0.2531 - val_loss: 1.9462 - learning_rate: 5.0000e-04
# Epoch 2/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 261ms/step - accuracy: 0.2782 - loss: 2.0159 - val_accuracy: 0.3469 - val_loss: 1.7647 - learning_rate: 5.0000e-04
# Epoch 3/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 264ms/step - accuracy: 0.2983 - loss: 1.8517 - val_accuracy: 0.4041 - val_loss: 1.5431 - learning_rate: 5.0000e-04
# Epoch 4/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - accuracy: 0.3320 - loss: 1.6537 - val_accuracy: 0.3265 - val_loss: 1.8669 - learning_rate: 5.0000e-04
# Epoch 5/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 264ms/step - accuracy: 0.2736 - loss: 2.0680 - val_accuracy: 0.3633 - val_loss: 1.5529 - learning_rate: 5.0000e-04
# Epoch 6/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 278ms/step - accuracy: 0.3468 - loss: 1.7361 - val_accuracy: 0.4776 - val_loss: 1.4289 - learning_rate: 5.0000e-04
# Epoch 7/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 266ms/step - accuracy: 0.4304 - loss: 1.4932 - val_accuracy: 0.3673 - val_loss: 1.5327 - learning_rate: 5.0000e-04
# Epoch 8/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - accuracy: 0.4057 - loss: 1.5659 - val_accuracy: 0.4776 - val_loss: 1.3526 - learning_rate: 5.0000e-04
# Epoch 9/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step - accuracy: 0.4740 - loss: 1.4069 - val_accuracy: 0.4653 - val_loss: 1.4539 - learning_rate: 5.0000e-04
# Epoch 10/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 255ms/step - accuracy: 0.4173 - loss: 1.5915 - val_accuracy: 0.4816 - val_loss: 1.2387 - learning_rate: 5.0000e-04
# Epoch 11/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 250ms/step - accuracy: 0.4769 - loss: 1.4617 - val_accuracy: 0.4082 - val_loss: 1.4748 - learning_rate: 5.0000e-04
# Epoch 12/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 248ms/step - accuracy: 0.5010 - loss: 1.2807 - val_accuracy: 0.4857 - val_loss: 1.3053 - learning_rate: 5.0000e-04
# Epoch 13/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 246ms/step - accuracy: 0.5559 - loss: 1.1798 - val_accuracy: 0.4531 - val_loss: 1.3305 - learning_rate: 5.0000e-04
# Epoch 14/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 269ms/step - accuracy: 0.6226 - loss: 1.0083 - val_accuracy: 0.6408 - val_loss: 0.9960 - learning_rate: 2.5000e-04
# Epoch 15/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 246ms/step - accuracy: 0.7167 - loss: 0.7943 - val_accuracy: 0.6041 - val_loss: 1.0333 - learning_rate: 2.5000e-04
#
# Training model 3 with LR=0.01, Kernel=(3, 3), Pool=(2, 2), Dense=512
# Epoch 1/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 271ms/step - accuracy: 0.1516 - loss: 4295.9541 - val_accuracy: 0.1469 - val_loss: 1.9798 - learning_rate: 0.0100
# Epoch 2/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - accuracy: 0.1468 - loss: 1.9705 - val_accuracy: 0.1592 - val_loss: 1.9140 - learning_rate: 0.0100
# Epoch 3/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 238ms/step - accuracy: 0.1831 - loss: 1.9747 - val_accuracy: 0.2571 - val_loss: 1.8747 - learning_rate: 0.0100
# Epoch 4/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 218ms/step - accuracy: 0.1963 - loss: 2.6454 - val_accuracy: 0.2653 - val_loss: 1.9039 - learning_rate: 0.0100
# Epoch 5/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 228ms/step - accuracy: 0.2122 - loss: 1.9186 - val_accuracy: 0.1878 - val_loss: 1.9250 - learning_rate: 0.0100
# Epoch 6/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 223ms/step - accuracy: 0.2166 - loss: 1.9065 - val_accuracy: 0.1755 - val_loss: 2.2591 - learning_rate: 0.0100
# Epoch 7/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 233ms/step - accuracy: 0.2496 - loss: 1.9372 - val_accuracy: 0.3878 - val_loss: 1.7080 - learning_rate: 0.0050
# Epoch 8/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 226ms/step - accuracy: 0.3012 - loss: 1.7779 - val_accuracy: 0.3388 - val_loss: 1.7830 - learning_rate: 0.0050
# Epoch 9/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 237ms/step - accuracy: 0.3063 - loss: 1.7972 - val_accuracy: 0.3714 - val_loss: 1.6599 - learning_rate: 0.0050
# Epoch 10/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 222ms/step - accuracy: 0.3231 - loss: 1.7130 - val_accuracy: 0.4694 - val_loss: 1.5629 - learning_rate: 0.0050
# Epoch 11/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 224ms/step - accuracy: 0.3910 - loss: 2.0318 - val_accuracy: 0.1837 - val_loss: 1.9247 - learning_rate: 0.0050
# Epoch 12/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 240ms/step - accuracy: 0.2404 - loss: 1.8652 - val_accuracy: 0.3878 - val_loss: 1.5785 - learning_rate: 0.0050
# Epoch 13/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 227ms/step - accuracy: 0.3636 - loss: 1.6301 - val_accuracy: 0.2898 - val_loss: 1.7215 - learning_rate: 0.0050
# Epoch 14/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 224ms/step - accuracy: 0.3567 - loss: 1.6042 - val_accuracy: 0.4939 - val_loss: 1.3798 - learning_rate: 0.0025
# Epoch 15/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 226ms/step - accuracy: 0.4712 - loss: 1.3987 - val_accuracy: 0.4490 - val_loss: 1.5687 - learning_rate: 0.0025
# Epoch 16/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 223ms/step - accuracy: 0.4608 - loss: 1.4574 - val_accuracy: 0.5184 - val_loss: 1.3268 - learning_rate: 0.0025
# Epoch 17/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 221ms/step - accuracy: 0.4880 - loss: 1.3729 - val_accuracy: 0.4122 - val_loss: 1.5332 - learning_rate: 0.0025
# Epoch 18/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.4849 - loss: 1.3949 - val_accuracy: 0.5918 - val_loss: 1.1736 - learning_rate: 0.0025
# Epoch 19/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 224ms/step - accuracy: 0.5258 - loss: 1.3391 - val_accuracy: 0.6204 - val_loss: 1.1054 - learning_rate: 0.0025
# Epoch 20/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 253ms/step - accuracy: 0.5428 - loss: 1.2717 - val_accuracy: 0.5469 - val_loss: 1.2415 - learning_rate: 0.0025
# Epoch 21/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 215ms/step - accuracy: 0.5114 - loss: 1.2341 - val_accuracy: 0.5959 - val_loss: 1.1324 - learning_rate: 0.0025
# Epoch 22/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step - accuracy: 0.5791 - loss: 1.1561 - val_accuracy: 0.5306 - val_loss: 1.2073 - learning_rate: 0.0025
# Epoch 23/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 234ms/step - accuracy: 0.5814 - loss: 1.0528 - val_accuracy: 0.5469 - val_loss: 1.1247 - learning_rate: 0.0012
# Epoch 24/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 230ms/step - accuracy: 0.6554 - loss: 0.9140 - val_accuracy: 0.6367 - val_loss: 0.9703 - learning_rate: 0.0012
# Epoch 25/25
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 221ms/step - accuracy: 0.6506 - loss: 0.9091 - val_accuracy: 0.6531 - val_loss: 0.9430 - learning_rate: 0.0012

# %% [markdown]
# Se comparan las métricas de los 3 modelos:

# %%
for i, hist in enumerate(histories):
    acc = hist.history['accuracy'][-1]
    val_acc = hist.history['val_accuracy'][-1]
    loss = hist.history['loss'][-1]
    val_loss = hist.history['val_loss'][-1]

    print(f"\n Modelo {i+1} :")
    print(f" - Accuracy (train):       {acc:.3f}")
    print(f" - Loss (train):           {loss:.3f}")
    print(f" - Accuracy (validation):  {val_acc:.3f}")
    print(f" - Loss (validation):      {val_loss:.3f}")
# Out:
#  Modelo 1 :
#  - Accuracy (train):       0.871
#  - Loss (train):           0.379
#  - Accuracy (validation):  0.722
#  - Loss (validation):      0.815
#
#  Modelo 2 :
#  - Accuracy (train):       0.679
#  - Loss (train):           0.921
#  - Accuracy (validation):  0.604
#  - Loss (validation):      1.033
#
#  Modelo 3 :
#  - Accuracy (train):       0.650
#  - Loss (train):           0.918
#  - Accuracy (validation):  0.653
#  - Loss (validation):      0.943

# %% [markdown]
# El modelo  1 es el que mejor generaliza para datos de validación. También tiene muy buena precisión para datos de entrenamiento, aunque eso podría indicar sobreentrenamiento, en este caso la precisión de validación es suficientemente buena con los pocos datos que se tienen.

# %%
#Seleccionamos manualmente el índice del mejor modelo que es el 1º
best_index = 0
best_model = models[best_index]
best_history = histories[best_index]

# %%
# Dibujamos la matriz de confusión del conjunto de entrenamiento del mejor modelo seleccionado
# Paso 1: Predicciones del modelo
y_pred_probs_train = best_model.predict(train_dataset)
y_pred_train = np.argmax(y_pred_probs_train, axis=1)

# Paso 2: Etiquetas reales extraídas del dataset
y_true_train = []
for _, labels in train_dataset:
    y_true_train.extend(np.argmax(labels.numpy(), axis=1))
y_true_train = np.array(y_true_train)

# Paso 3: Obtener nombres de clase
class_names = train_dataset.class_names

# Paso 4: Matriz de confusión
cm = confusion_matrix(y_true_train, y_pred_train)

# Paso 5: Dibujar la matriz
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title(f"Matriz de confusión de entrenamiento - Mejor Modelo #{best_index+1}")
plt.xlabel("Predicción")
plt.ylabel("Real")
plt.tight_layout()
plt.show()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step

# %%
# Dibujamos un gráfico que muestra la variación de la pérdida en función de las épocas para el conjunto de entrenamiento del mejor modelo.
plt.plot(best_history.history['loss'], label='Pérdida entrenamiento')
plt.plot(best_history.history['val_loss'], label='Pérdida validación')
plt.title(f"Evolución de la pérdida - Mejor Modelo #{best_index+1}")
plt.xlabel("Épocas")
plt.ylabel("Pérdida")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Una vez conocemos cuándo se sobreentrena el modelo (gracias a los datos de validación) podemos usar los datos de validación para un segundo entrenamiento y que el modelo se ajuste para nuevas imágenes.
#
# Según la gráfica no hay sobreentrenamiento, aunque hay algunos máximos en la pérdida de validación (época 8) pueden ser movimientos de exploración que ayudan a salir de mínimos locales.

# %%
# -------------------------------
# Segundo ciclo de entrenamiento (usando validación para entrenar y test para validar)
# -------------------------------
print("\nEntrenando segunda vez con datos de validación para entrenar...")
    
second_history = best_model.fit(
    val_dataset,  # Entrenamos usando el conjunto de validación como datos de entrenamiento
    epochs=2,
    callbacks=[tensorboard_callback, reduce_lr]
)

# Evaluación en test después del segundo ciclo de entrenamiento
test_loss, test_acc = best_model.evaluate(test_dataset)
print(f"Evaluación en test: Loss={test_loss}, Accuracy={test_acc}")
# Out:
# Entrenando segunda vez con datos de validación para entrenar...
# Epoch 1/2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6784 - loss: 1.0424 - learning_rate: 2.5000e-04
# Epoch 2/2
# C:\Users\anruk\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\callbacks\callback_list.py:145: UserWarning: Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7236 - loss: 0.8013 - learning_rate: 2.5000e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7532 - loss: 0.6929
# Evaluación en test: Loss=0.7581828236579895, Accuracy=0.7352941036224365

# %% [markdown]
# Mejora ligeramente la precisión en datos de test, que no se utilizan en el entrenamiento ni para validar durante este.

# %%
# Realizamos predicciones sobre el conjunto de test
y_pred_probs_test = best_model.predict(test_dataset)
y_pred_test = np.argmax(y_pred_probs_test, axis=1)

# Extraemos las etiquetas reales del test_dataset
y_true_test = []
for _, labels in test_dataset:
    y_true_test.extend(np.argmax(labels.numpy(), axis=1))
y_true_test = np.array(y_true_test)

# Nombres de clases
class_names = test_dataset.class_names

# Calculamos métricas básicas
accuracy = accuracy_score(y_true_test, y_pred_test)
precision = precision_score(y_true_test, y_pred_test, average='weighted')
recall = recall_score(y_true_test, y_pred_test, average='weighted')
f1 = f1_score(y_true_test, y_pred_test, average='weighted')

# Mostramos las métricas
print(f"Métricas de evaluación en datos de test para el Modelo:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print("\n")

# Matriz de confusión
cm = confusion_matrix(y_true_test, y_pred_test)
plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title(f"Matriz de confusión en datos de test - Modelo ")
plt.xlabel("Predicción")
plt.ylabel("Real")
plt.show()

# Informe por clase
print("Informe de clasificación detallado por clase:")
print(classification_report(y_true_test, y_pred_test, target_names=class_names))

# Visualización de la distribución de predicciones por clase
plt.figure(figsize=(12, 6))
for i, class_name in enumerate(class_names):
    class_indices = np.where(y_true_test == i)[0]
    correct_preds = sum(y_pred_test[class_indices] == i)
    plt.bar(i, correct_preds / len(class_indices) if len(class_indices) > 0 else 0)

plt.xticks(range(len(class_names)), class_names, rotation=45, ha='right')
plt.ylim(0, 1)
plt.title("Tasa de acierto por clase")
plt.ylabel("Proporción de predicciones correctas")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Métricas de evaluación en datos de test para el Modelo:
# Accuracy: 0.7353
# Precision: 0.7347
# Recall: 0.7353
# F1-Score: 0.7310
# Informe de clasificación detallado por clase:
#               precision    recall  f1-score   support
#
#         fish       0.55      0.53      0.54        34
#    jellyfish       0.89      0.91      0.90        34
#      penguin       0.88      0.88      0.88        34
#       puffin       0.84      0.76      0.80        34
#        shark       0.58      0.53      0.55        34
#     starfish       0.70      0.94      0.80        34
#     stingray       0.71      0.59      0.65        34
#
#     accuracy                           0.74       238
#    macro avg       0.73      0.74      0.73       238
# weighted avg       0.73      0.74      0.73       238

# %% [markdown]
# Gracias a utilizar más datos para entrenar (los de validación) se mejora la precisión del modelo en datos de test, que no se han usado en ningún entrenamiento.
